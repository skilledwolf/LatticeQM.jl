# %%
# using Distributed
# ifelse(nprocs()<2, addprocs(7), nothing);

# @everywhere using LinearAlgebra
# @everywhere LinearAlgebra.BLAS.set_num_threads(1) # set number of threads for BLAS

# %%
using LinearAlgebra
LinearAlgebra.BLAS.set_num_threads(6) # set number of threads for BLAS

# %%
using Plots
# using Revise

# %%
using LatticeQM

# %% [markdown]
# # Tutorial: Twisted honeycomb lattices

# %%
@time lat = Geometries.honeycomb_twisted(11)
Geometries.smoothdisplaceZ!(lat, 0.045)

# %%
plot(lat, 3; supercell=Structure.Lattices.getneighborcells(lat, 1; halfspace=false, innerpoints=true, excludeorigin=false), sort="layer", markersize=1.5)

# %% [markdown]
# ## Model

# %%
@time valley = Operators.valley(lat; spinhalf=false)
@time H = Operators.graphene(lat; tz=0.32, format=:sparse, mode=:nospin) # specifying format is important here!
filling = 0.5 + 6.0 / hopdim(H) # for spinful
# Operators.setfilling!(H, 0.5; nk=6) # should be 3 min on 1 core (Apple M1)
nothing

# %%
ks = kpath(lat, ["μ2", "γ", "κ", "κ'", "γ", "μ"]; num_points=100)
k0 = ks[:,5]
h0 = H(k0)
ishermitian(sparse(h0))

# %% [markdown]
# ### Bands

# %%
# using LinearAlgebra
# using SparseArrays

# ks = kpath(lat, ["μ2", "γ", "κ", "κ'", "γ", "μ"]; num_points=100)

# k0 = ks[:,5]
# h0 = H(k0)

# @time Matrix(h0)
# @time e0, v0 = eigen(Matrix(h0))
# @time e0, v0 = eigen(Hermitian(Matrix(h0)))

# %%
ks = kpath(lat, ["μ2", "γ", "κ", "κ'", "γ", "μ"]; num_points=100)
bands = getbands(H, ks, valley; format=:sparse, num_bands=25)

# %%
p1 = plot(bands; size=(300,250), markercolor=:diverging_bkr_55_10_c35_n256, colorbar=true)
p2 = plot(bands; ylim=(-0.00,0.04), size=(300,250), markercolor=:diverging_bkr_55_10_c35_n256, colorbar=true)

plot(p1,p2; size=(600,200))

# %%
H = Operators.graphene(lat; mode=:spinhalf, format=:sparse, tz=0.45)
Operators.addrashba!(H, lat, r -> 0.04 * sign(r[3]))
Operators.addzeeman!(H, lat, r -> 0.04 * [0.0, 0.0, sign(r[3])])
Operators.setfilling!(H, 0.5; nk=12)

# kgrid = LatticeQM.Utils.randomgrid(;nk=8^2, rot_symmetry=6, B=Structure.getB(lat))
kgrid = Structure.regulargrid(;nk=8^2)
ωs = collect(range(-0.0015, length=100, stop=0.001))
ldos = Spectrum.ldos(H, kgrid, ωs; Γ=0.0005, format=:sparse, num_bands=25);

# %%
ldos0 = ldos[1:2:hopdim(H)] + ldos[2:2:hopdim(H)]
plot(lat, ldos0; clims=(0,maximum(ldos)), markercolor=:inferno, colorbar=true)

# %%
ldos0 = ldos[1:2:hopdim(H)] - ldos[2:2:hopdim(H)] 
cmax = maximum(abs.(ldos0)) 
plot(lat, ldos0; clims=(-cmax,cmax), colorbar=true)
